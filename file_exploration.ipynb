# %%
import glob
import docx
import re
import difflib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import collections
import os

# %%
pat = re.compile(r'[\-–,\?!\$%\;:\.\"]')

# %%
SEARCHING_HEADERS = set(['Proposal Title', 'Vertical(s)', 'Contributor(s) Name(s) and Title(s)',
                                                  'Disclosure of Any Conflict of Interests', 'Opportunity/Problem Being Solved',
                                                  'Impediments to Implementation', 'Recommended Actions',
                                                  'Program Type', 'Authority', 'Involved Agencies and/or Programs',
                                                  'Funding', 'Economic Benefits', 'Job Creation',
                                                  'Environmental Benefits', 'Equity Benefits',
                                                  'Stakeholder support/opposition', 'Key Experts'])
CSV_PROVIDED_HEADERS = set(['Proposal Title', 'Vertical(s)', 'Contributor(s) Name(s) and Title(s)',
                                                     'Authority', 'Funding', 'Involved Agencies and/or Programs'])
csv_headers = {'Proposal Title': 'Proposal Title', 'Vertical(s)': 'Verticals (max 3)',
              'Contributor(s) Name(s) and Title(s)': 'Contributor(s)',
              'Authority': 'Authority', 'Funding': 'Funding', 'Involved Agencies and/or Programs': 'Agency/Exec. Office'}
SEARCHING_HEADERS
# Out:
# {'Authority',
#  'Contributor(s) Name(s) and Title(s)',
#  'Disclosure of Any Conflict of Interests',
#  'Economic Benefits',
#  'Environmental Benefits',
#  'Equity Benefits',
#  'Funding',
#  'Impediments to Implementation',
#  'Involved Agencies and/or Programs',
#  'Job Creation',
#  'Key Experts',
#  'Opportunity/Problem Being Solved',
#  'Program Type',
#  'Proposal Title',
#  'Recommended Actions',
#  'Stakeholder support/opposition',
#  'Vertical(s)'}

# %%
filenames = glob.glob('ALREADY IN D BASE_/*.docx') + glob.glob('ALREADY IN D BASE_/*/*.docx')
filenames[:5]
# Out:
# ['ALREADY IN D BASE_\\  Enactment of the “Energy Efficiency Acceleration Act of 2021” (the “EEAA”) .docx',
#  'ALREADY IN D BASE_\\ Expansion of the State Energy Program (SEP).docx',
#  'ALREADY IN D BASE_\\123 Agreements Through a Climate Lens.docx',
#  'ALREADY IN D BASE_\\A Building Energy Performance Standard for Federal Buildings.docx',
#  'ALREADY IN D BASE_\\A Just Transition for Coal Country_ Beyond Economic Recovery to Zero Carbon Economic Revival.docx']

# %%
len(filenames)
# Out:
# 218

# %%
df = pd.read_csv('cleenProjectLibrary.csv')
df.head()
# Out:
#                                       Proposal Title  \
# 0  Budget Neutral Federal Fleet Emissions Reducti...
# 1  Sustainable Public Procurement: Mandates, Metr...
# 2                FERC Proceeding on System Peakiness
# 3  Transform All Public Buildings by Reimagining ...
# 4  Expand federal STEM internships opportunities ...
#
#                               Contributor(s)  \
# 0                  Jeff Eckel,Guy Van Syckle
# 1    Steven Schooner,"Markus Speidel, Ph.D."
# 2                           Richard Kauffman
# 3                               Jason Hartke
# 4  Anna Lising,Laurie Wiegand,Jeanette Pablo
#
#                                   Prof. Affiliations  \
# 0                                   Hannon Armstrong
# 1            George Washington University Law School
# 2                                   Generate Capital
# 3      International WELL Building Institute, ex-DOE
# 4  Clean Energy for Biden, Utility Advantage, Ene...
#
#                 Verticals (max 3)  \
# 0                Auto & Transport
# 1              Energy,Equity & EJ
# 2                          Energy
# 3  Buildings & Affordable Housing
# 4                     Equity & EJ
#
#                                            Authority     Funding  \
# 0                                    New legislation  No funding
# 1  Existing authority,Executive order,New legisla...  No funding
# 2                                 Existing authority  No funding
# 3                                 Existing authority  No funding
# 4                                 Existing authority     Funding
#
#                                      Misc. Agency/Exec. Office  \
# 0                              Procurement             DOE,GSA
# 1   WH Press,Procurement,Challenges/Awards              GSA,WH
# 2                                      NaN                FERC
# 3  Fed/State Partners. ,Pub/Priv Partners.             DOE,GSA
# 4                                      NaN                 DOE
#
#                                        Full Proposal Supporting documents
# 0  10-14_ZEV-ESPCs.docx.pdf (https://dl.airtable....                  NaN
# 1  "Sustainable Public Procurement_ Mandates, Met...                  NaN
# 2  FERC Proceeding on System Peakiness_docx.pdf (...                  NaN
# 3  Transform All Public Buildings by Reimagining ...                  NaN
# 4  "Expand federal STEM internships opportunities...                  NaN

# %%
sum(df['Full Proposal'].str.contains('123 Agreements Through a Climate Lens', case=False))
# Out:
# 1

# %%
file = filenames[1]

def loose_match(header, search_list, diff=3):
    if len(header)<=1:
        return None
    for element in search_list:
        if count_diff(element.upper(), header.upper())<=3:
            return header
    return None

def get_information(filename, use_csv=True):
    information = collections.defaultdict(list)
    
    doc = docx.Document(filename)    
    proposal_name = os.path.splitext(os.path.basename(filename))[0]
    
    if use_csv and sum(df['Full Proposal'].str.contains(proposal_name))==1:
        row = df.loc[df['Full Proposal'].str.contains(proposal_name)]
        for header in CSV_PROVIDED_HEADERS:
            information[header] = row[csv_headers[header]].str.split(',')
        search_list = SEARCHING_HEADERS - CSV_PROVIDED_HEADERS
    else:
        search_list = SEARCHING_HEADERS
    
    current_header = None
    ignore = False
    for i, paragraph in enumerate(doc.paragraphs):
        val = paragraph.text
        val = val.replace('\t','').replace('\n','').strip()
        match = loose_match(val, search_list)
        #print(match)
        if match:
            current_header = match
            ignore = False
        else:
            csv_match = loose_match(val, CSV_PROVIDED_HEADERS)
            if use_csv and csv_match:
                current_header = csv_match
                ignore = True
            if current_header and not ignore:
                information[current_header].append(val)
    print('Missing headers:', set(SEARCHING_HEADERS)-set(information.keys()))
    return information

information = get_information(file, use_csv=True)
information
# Out:
# Missing headers: {'Contributor(s) Name(s) and Title(s)', 'Disclosure of Any Conflict of Interests', 'Vertical(s)', 'Recommended Actions', 'Proposal Title', 'Stakeholder support/opposition'}
# defaultdict(list,
#             {'PROPOSAL TITLE': ['Expansion of the State Energy Program (SEP)'],
#              'Verticals': ['Buildings, energy, environment, affordable housing, infrastructure, transportation, innovation, agriculture, circular economy, consumer products, manufacturing, environmental justice, and state-local-federal interface.',
#               'Contributor',
#               'Jeff Genzer, Counsel, NASEO',
#               'Conflict of Interest',
#               'I have been counsel to NASEO since the organization began in 1986.  NASEO represents the state energy offices in all the states, territories and Washington, DC.  NASEO is committed to representing the views of the states in Washington, DC and to assist the states in developing energy policies and programs that assist the economy, promote energy efficiency, renewable energy, respond to climate change, prepare and respond to energy emergencies, address cyber and physical security and assist in economic development.'],
#              'Opportunity/Problem Being Solved': ['The State Energy Program is an umbrella program that links state and federal energy policy and programs.  Any stimulus action intended to address the energy problems in the “verticals” noted above will require state leadership and state action.  A program that operates in every state, which really only needs more money to be more successful, is the crux of SEP.'],
#              'Impediments to Implementation': ['Lack of Money.'],
#              'Program Type': ['Program Expansion and modification to include new activities.'],
#              'Authority': ['Existing Authority:  42 USC 6321-6325, with a special focus on 42 USC 6322(d).  This could be modified to expand to other functions and any stimulus would require a waiver of the cost-share requirement and regulatory limitations contained in 10 CFR 420.18.  The regulations have existed for many years and are well understood at the state level (10 CFR 420).'],
#              'Involved Agencies and/or Programs': ['U.S. Department of Energy'],
#              'Funding': ['SEP is presently funded at $62.5 million/year.  Under the FY’21 House Energy and Water Development Appropriations Bill, the House provided supplemental funding of an additional $730 million.  Under the American Recovery and Reinvestment Act (ARRA), $3.1 billion was provided.  The minimum level of funding necessary to address the base program would be $3.1 billion.  In addition, additional functions would require additional funding, including, but not limited to:  a) $18 billion for the SEP component of the “Open Back Better” bill from Rep. Blunt Rochester and Senator Smith (HR 7303/S. 4060 – also included in HR 2 and HR 4447), focusing on resiliency, energy efficiency and renewable energy upgrades for mission-critical facilities (schools, hospitals, etc.); b) $500 million/year for 5 years for a proposal from Rep. Tonko to expand the NY “flex-tech” program to assist domestic manufacturers to retool and become more competitive and more energy efficient; c) Stabenow/Schumer proposal to expand state-level transportation planning to address “holistic” approaches to EVs and clean transportation - $50 million/year for 5 years; and d) Welch proposal to expand energy service performance contracting at the state and local level - $100 million/year for 5 years. This list does not include funding for the “Hope for HOMES and HOMES bills that would work through the state energy offices (Welch/McKinley), which we strongly support. In order to be most effective, we recommend that programs be expanded and allow spending to occur over 10 years in order to stimulate job growth and preservation, and jump-start the clean-energy economy.',
#               'Here are three examples:',
#               'Utilizing SEP, you could create a streamlined high-volume Energy Service Performance Contracting public facility retrofit program in every interested state, which we would expect to be virtually every state.  This could be the “Open Back Better” bill noted above, which is set forth in authorizing legislation, but could also be streamlined in a stimulus bill like ARRA and converted into appropriations language.  If the total price tag of the legislation is deemed too high for the Senate, the focus on resilience investments (with energy efficiency, renewable energy and smart technologies) could be coupled with pre-disaster mitigation planning money pursuant to the Disaster Recovery and Reform Act (DRRA) and state and local capital improvements.  While it would be critical to have a 10-year horizon in such an effort, in order to create and maintain job growth and clean jobs, a smaller version could be for a shorter period and could focus on reducing energy consumption of state and local facilities by 20%.  There are literally hundreds of examples of these types of Energy Service Performance Contracting (ESPC) programs operational across the country (see, e.g., Lawrence Berkeley National Laboratory data base). These successful private financing programs have operated across both blue and red states (see, e.g., Texas “LoanStar” program - $600+ million in energy efficiency investments with zero defaults; or Nebraska “HELP” program – over $350 million in energy efficiency and renewable energy investments with less than $200,000 in defaults).  The additional innovation is connecting it to resilience activities. This program could be effective at less than the $18 billion for SEP from the Blunt-Rochester bill, but in order to have a fully transformative impact the highest number possible would be advisable.  The existing ESPC programs are in the $5-7 billion range annually, and are generally managed/supervised by the state energy offices, who also utilize the SEP funding.  Every state has a state energy office, and there are approximately 3000+ state energy officials across the United States.',
#               'Green Hydrogen – Long duration storage and decarbonization of the natural gas sector could occur with this new and innovative program.  To start, a state-utility roadmapping exercise could develop market-guiding policy recommendations that utilize excess renewable energy to produce green hydrogen to deliver clean peak grid support and injection (up to 10%) of green hydrogen into the existing natural gas system.  This is geared toward both single state analytical (economic, environmental, energy) and policy development activities, as well as a requirement for multi-state/regional collaborative activities.  Funding of about $50 million for three years “ be a good start.',
#               'Residential Green Construction Apprentices – One of our critical failings as a country, is not working hard enough to expand “green jobs” programs, especially in hard-hit communities across the U.S.  Public-private partnership programs designed to train unskilled workers (equity should be a key) for various construction trades, including apprentice-track trades (e.g., electrical and plumbing), could utilize advanced, commercially available building materials; training proper air sealing and insulation, etc.  Training in partnership with builders committed to ENERGY STAR or similar new construction with wage incentives should be the baseline.  This program could also be linked to building code compliance training, including especially building energy code compliance training.  The goal would be to train at least 100,000 workers over three years.  The program should be developed in conjunction with the Buildings Technology Office (BTO) of the Energy Efficiency and Renewable Energy division at DOE.  They could develop a model that states could adapt.  This would also be consistent with the “Green Jobs” legislation sponsored by Rep. Rush (D-IL) and Rep. Upton (R-MI).  Energy jobs data is based on the work of the US Energy and Employment Report (USEER) and E4theFuture.  This could also be utilized in conjunction with Rep. Welch’s “Hope for HOMES” and “HOMES” legislation.  At least $1 billion/year for three years should be dedicated to this effort.',
#               'Existing Home Retrofit Incentives tied to the Home Energy Score for all homes, with a special program for affordable/low-income housing (two parts) – a) State Existing Home Retrofit Incentives linked to Home Energy Score  ((HES) .  State programs utilize HES would identify energy efficiency measures in recently purchase homes with federal funding to pay for 75% of HES cost and 25% to be covered by local contractors or major retailers/product providers (e.g., Home Depot) – a public-private partnership intended to move to a large scale and self-sustaining market over the period of the funding.  This program could be linked to residential retrofit tax incentives, for ENERGY STAR products, including insulation. b) The same program could be adapted for use in the affordable housing/low-income housing sector where HES results in an HES-type building label (cost should be covered by federal funding) and covers the cost of the energy efficiency measures.  The label provides very modest “equity” value for the low-income homeowner.  The obvious linkage here is with the Low-Income Weatherization Assistance Program, but the DOE rules are restrictive, so this should be a separate activity.  However, funds provided from the LIHEAP program (up to 15% of LIHEAP funds without a waiver can be shifted to weatherization-type activities, though they are not limited by the specific DOE rules).  The HES cost is approximately $300/home ($300 million/year for 1 million homes/year = $900 million + funding support for the actual measures at $3 billion/year for 3 years = $9 billion).'],
#              'Economic Benefits': ['A study by Oak Ridge National Laboratory determined that under SEP for every federal dollar invested over $7 in energy savings is produced.  Again, this focused just on energy savings, and did not address the myriad of other economic benefits.  That same study determined that for every federal dollar, over $11 in non-federal funds are leveraged.  Obviously, if one extrapolates from the funding set forth in the prior sentence, then the economic benefits would be substantial, and would not be delayed by creating a new program.'],
#              'Job Creation': ['Assuming that 9.5 – 10 job years are created for every $1 million in SEP related activities (see analyses of Don Gilligan (NAESCO), Tim Unruh (former Federal Energy Management Program and NASESCO Executive Director) and the work of the US Energy and Employment Report (BW Research, EFI, NASEO), then the $3.1 billion for the ARRA-level SEP funding under a new stimulus bill would create an addition 31,000 jobs.  For the $18 billion under the “Open Back Better” bill (see HR 7303/S. 4060), which is projected to produce $110 billion in economic activity (1/2 manufacturing, ¼ local contracting work and ¼ other work), such a dramatic funding level would produce 1.1 million additional jobs.  You can extrapolate job creation from the other categories of funding set forth above.'],
#              'Environmental Benefits': ['Over the years, individual state programs have evaluated reductions in criteria pollutants and greenhouse gas emissions from state programs.  Depending on the level of funding, the environmental benefits would be enormous for both criteria pollutants and greenhouse gas emissions.  With 38% of energy use attributable to buildings, the reductions in energy use will be substantial.  In addition, if a robust EV program is coupled with a targeted greenhouse gas emissions program/hydrogen program, then an even larger emissions reduction could be generated.'],
#              'Equity Benefits': ['NASEO has an Equity Committee and has worked hard to assist states in instituting programs that target low-income Americans. Again, the size of the benefit, both in terms of neighborhoods, job creation and new clean-energy facilities is difficult to quantify and will depend on the target of the programs, but the benefits would be substantial.'],
#              'Key Experts': ['Jeff Genzer (',
#               'David Terry ( Executive Director)',
#               'Andrew McAllister ( Energy Commissioner)',
#               'We can provide more names upon request.']})

# %%
paragraph = doc.paragraphs[0]
print(paragraph.runs[0].text)
print(paragraph.runs[0].bold)
print(paragraph.style.font.highlight_color)
# Out:
# Proposal Title
# True
# None

# %%
header_counts = collections.defaultdict(int) # count how many times each unique header comes up
for file in filenames:
    try:
        doc = docx.Document(file)
        for paragraph in doc.paragraphs:
            text = paragraph.text.replace('\n','').replace('\t','').replace(':','')
            if len(paragraph.runs)>0:
                if paragraph.runs[0].bold:
                    header_counts[text.upper().strip()] += 1
    except:
        continue
        
print(len(header_counts))
header_counts
# Out:
# 312
# defaultdict(int,
#             {'PROPOSAL TITLE': 200,
#              'VERTICALS': 203,
#              'CONTRIBUTOR(S) NAME(S) & TITLE(S)': 200,
#              'DISCLOSURE OF ANY CONFLICT OF INTEREST': 196,
#              'OPPORTUNITY/PROBLEM BEING SOLVED': 182,
#              'IMPEDIMENTS TO IMPLEMENTATION': 199,
#              'RECOMMENDED ACTIONS': 203,
#              'PROGRAM TYPE': 198,
#              'AUTHORITY': 201,
#              'INVOLVED AGENCIES AND/OR PROGRAMS': 204,
#              'FUNDING': 195,
#              'ECONOMIC BENEFITS': 199,
#              'JOB CREATION': 196,
#              'ENVIRONMENTAL BENEFITS': 200,
#              'EQUITY BENEFITS': 198,
#              'STAKEHOLDER SUPPORT AND OPPOSITION': 166,
#              'KEY EXPERTS': 197,
#              'REFERENCE MATERIALS': 173,
#              'CONTRIBUTOR': 1,
#              'CONFLICT OF INTEREST': 1,
#              'TITLE': 2,
#              'DISCLOSURE OF ANY CONFLICT OF INTEREST NO CONFLICTS': 1,
#              'STAKEHOLDER SUPPORT AND OPPOSITION UNDETERMINED': 1,
#              'KEY EXPERTS CONTACTS AVAILABLE UPON REQUEST': 1,
#              'REFERENCE MATERIALS ;': 1,
#              'PROBLEM BEING SOLVED/OPPORTUNITY': 23,
#              'CONTACT PLEASE SEND YOUR COMPLETED SUBMISSIONS TO OUR DIRECTORS OF POLICY RESEARCH.': 36,
#              'NO COST IMPACTS. COULD BE INCLUDED IN A MAJOR INFRASTRUCTURE BILL.': 1,
#              'REVENUE ADDED TO THE ECONOMY, INCREASED TAX REVENUE COLLECTION DUE TO A LOWER COST OF CAPITAL PROVIDED BY “TAX EQUITY” INVESTORS.  INCREASED CAPITAL WILL FUND MORE INFRASTRUCTURE. AND THE INCREASED ECONOMIC RENT EARNED FROM THAT INFRASTRUCTURE WILL MEAN MORE TAX REVENUE COLLECTED FROM THIS SECTOR OF THE ECONOMY.': 1,
#              'ACCELERATING THE DEPLOYMENT OF NEXT GENERATION BATTERY SWAP EV CHARGING INFRASTRUCTURE': 1,
#              'PAUL BLEIBERG, SENIOR VICE PRESIDENT, NATIONAL MILK PRODUCERS FEDERATION. DAVID BABSON, PROGRAM DIRECTOR, ARPA-E. SAM WADE, FORMER CHIEF, TRANSPORTATION FUEL BRANCH, CALIFORNIA AIR RESOURCES BOARD.': 1,
#              'EXISTING AUTHORITY, REQUIRES NEW REGULATION, REQUIRES NEW LEGISLATION': 7,
#              'CLEEN PROPOSAL TEMPLATE': 1,
#              'THE CLEEN PROJECT': 42,
#              'PROBLEM': 2,
#              'TRADITIONAL SOLUTION': 2,
#              'PROPOSED NEW SOLUTION': 2,
#              'ADDITIONAL BENEFITS': 2,
#              'SUPPORT UTILITIES (MORE SALES), VEHICLE OEMS, LARGE TRANSPORT USERS (COMMERCIAL FLEETS, TNC, GOVERNMENT FLEETS), ZERO ENERGY TRANSPORTATION ALLIANCE, ENERGY STORAGE ASSOC': 2,
#              'OPPOSE UTILITIES (DECREASE CAPEX SPENDING), OIL & GAS COMPANIES': 2,
#              'NO COST. SHOULD INCREASE TAX REVENUE. COULD BE INCLUDED IN A MAJOR INFRASTRUCTURE BILL.': 1,
#              'REVENUE ADDED TO THE ECONOMY, INCREASED TAX REVENUE COLLECTION. MOST PRIVATE SECTOR CLEAN ENERGY INVESTMENTS ARE MADE THROUGH UNTAXED PARTNERSHIPS/LLCS AVAILABLE ONLY TO THE WEALTHY. PUBLICLY TRADED REITS AND MLPS ENABLE INDIVIDUALS TO OWN FRACTIONAL SHARES IN CLEAN ENERGY INVESTMENTS, GROWING THE AMOUNT OF PRIVATE SECTOR CAPITAL FUNDING CLEAN ENERGY PROJECTS. MORE CAPITAL WILL FUND MORE INFRASTRUCTURE. AND THE INCREASED ECONOMIC RENT EARNED FROM THAT INFRASTRUCTURE WILL MEAN MORE TAX REVENUE COLLECTED FROM THIS SECTOR OF THE ECONOMY.': 1,
#              'PROGRAM MODIFICATION': 8,
#              'EXISTING AUTHORITY': 9,
#              'DISCLOSURE OF ANY CONFLICT OF INTEREST N/A': 2,
#              'REFERENCE MATERIALS / NOTES': 1,
#              'MODERN FARMER': 1,
#              '': 26,
#              'ECONOMIC ANALYSIS OF CLIMATE LEADERSHIP COUNCIL PROPOSAL - ACCORDING TO A NEW ANALYSIS BY THUNDER SAID ENERGY, THE COUNCIL’S CARBON DIVIDENDS PLAN WOULD\xa0UNLOCK $1.4 TRILLION\xa0IN NEW US CAPITAL INVESTMENT, CREATE\xa01.6 MILLION JOBS, REDUCE US CARBON EMISSIONS BY\xa057% BY 2035, AND ENHANCE AMERICAN INDUSTRIAL COMPETITIVENESS.': 1,
#              'AMERICA’S CARBON ADVANTAGE - A FIRST-OF-ITS-KIND STUDY UNDERSCORES AMERICA’S STRIKING CARBON EFFICIENCY ADVANTAGE OVER ITS KEY TRADING PARTNERS. BY LEADING AND ESTABLISHING A NEW ORDER ON CLIMATE AND TRADE, AMERICA CAN LEVERAGE ITS SIGNIFICANT CARBON ADVANTAGE TO ENHANCE THE COMPETITIVENESS OF US BUSINESSES, BRING MANUFACTURING JOBS BACK TO THE US AND BOOST CLIMATE AMBITION AROUND THE WORLD.': 1,
#              'ENERGY, BUILDINGS AND AFFORDABLE HOUSING AND ENVIRONMENTAL JUSTICE': 1,
#              'PROGRAM MODIFICATION / NEW PROGRAM': 1,
#              'NOT A PROGRAM.': 1,
#              'EXISTING AUTHORITY.': 1,
#              'REVIVE THE OBAMA ADMINISTRATION’S DEPARTMENT OF LABOR/ BUREAU OF LABOR STATISTICS’ 2013 “GREEN JOBS INITIATIVE” (AKA “CLEANTECH”) THEREBY DESIGNATING IT AS A FEDERALLY MONITORED INDUSTRY.': 1,
#              'ECONOMIC AND JOB BENEFITS': 1,
#              'US DOL, BUREAU OF LABOR STATISTICS 2013 REPORT ON CLEAN JOBS.': 1,
#              'CANADIAN PROPOSAL TO INCLUDE CLEANTECH AS DEFINED INDUSTRY WITHIN NATURAL RESOURCES SECTOR.': 1,
#              '2017 CANADIAN FEDERAL FIRST REPORT ON NEWLY DESIGNATED CLEANTECH INDUSTRY DATA': 1,
#              'CLEANTECH SECTOR ECONOMIC IMPACT STUDY AUSTIN TX': 1,
#              'FASTEST GROWING JOBS BY STATE.  FEB. 2019': 1,
#              'CLEAN JOBS AMERICA 2020-E2': 1,
#              'BUREAU OF ECONOMIC ANALYSIS “INTRODUCING THE OUTDOOR RECREATION SATELLITE ACCOUNT”.': 1,
#              'COLLABORATIVE EXPERIENCES TO ACCELERATE RESILIENT SYSTEMS (CEARS) A PUBLIC-PRIVATE PARTNERSHIP TO DEPLOY AND SHARE LEARNINGS FROM PROJECTS TO IMPROVE ELECTRIC SYSTEM RESILIENCE': 1,
#              'PROGRAM TYPE, AUTHORITY AND RECOMMENDED ACTIONS': 1,
#              'SUPPLY': 1,
#              'DEMAND': 1,
#              'INVESTORS': 1,
#              'AGENDA TO OPEN WITH BRIEF PRESENTATION ON LIGHT DUTY TRANSPORTATION EMISSIONS, EMPLOYMENT AND MARKET TRENDS IN THE US AND GLOBALLY.  ROUNDTABLE TO INCLUDE OVERVIEW OF ROLE OF EACH ACTOR IN THE OVERALL TRANSPORT SYSTEM, WHAT ACTIONS THEY HAVE TAKEN AND HAVE PLANNED, DISCUSSIONS BETWEEN ENTITIES ON THE SUPPLY AND DEMAND SIDE AROUND THE VOLUMES AND PRODUCTS THEY ANTICIPATE BEING READY TO PRODUCE OR BUY, AND DISCUSSION AMONG ALL ABOUT WHAT POLICIES AND INVESTMENTS ARE NEEDED TO ACCELERATE THE TRANSITION, CREATE JOBS AND SUPPORT COMMUNITIES TO MAXIMIZE OPPORTUNITY AND MINIMIZE RISK OF FALLING BEHIND IN THE TRANSITION.': 1,
#              'OUTCOMES OF THE ROUNDTABLE COULD INCLUDE INCREASED AMBITION AND COLLABORATION AMONG DIFFERENT ACTORS IN THE SYSTEM, ANNOUNCEMENTS OF PROJECTS AND PARTNERSHIPS THAT BRING TOGETHER PRIVATE COMPANIES, PRIVATE CAPITAL, LOCAL LABOR OR JOB TRAINING PROGRAMS AND UNIVERSITIES, SUPPORTED WITH PUBLIC POLICY, INCENTIVES OR DIRECT STIMULUS SPENDING.': 1,
#              'DEPT OF ENERGY EXAMPLE WOULD FOLLOW A SIMILAR MODEL, INVITING': 1,
#              'EXISTING AUTHORITY (FY2020 NDAA; RAMI ACT OF 2014 AS AMENDED),': 1,
#              'NOT A PROGRAM': 1,
#              'SUPPORT STATE PEOPLE’S COUNSEL, CONSUMER ADVOCATES, LOW-INCOME ADVOCATES, NEUAC, AFFORDABLE HOUSING AND ENVIRONMENTAL ADVOCATES, COMMUNITY SOLAR AND ENERGY EFFICIENCY COMPANIES, COMMUNITY ORGANIZATIONS AND SOCIAL JUSTICE ADVOCATES': 5,
#              'POTENTIAL OPPOSITION HUD, HHS, USDA, UTILITIES, PSC/PUCS': 1,
#              'CREATION OF ADVANCED MANUFACTURING INNOVATION COUNCIL (AMIC) AND EXPAND INVESTMENT IN THE NATIONAL NETWORK OF MANUFACTURING USA INSTITUTES': 1,
#              'MANUFACTURING, INNOVATION': 1,
#              'NEW PROGRAM': 2,
#              'REQUIRES NEW LEGISLATION': 2,
#              'SUPPORT STATE PEOPLE’S COUNSEL, CONSUMER ADVOCATES, LOW-INCOME ADVOCATES, NEUAC, AFFORDABLE HOUSING AND ENVIRONMENTAL ADVOCATES, COMMUNITY SOLAR AND ENERGY EFFICIENCY COMPANIES, COMMUNITY ORGANIZATIONS AND SOCIAL JUSTICE ADVOCATES, UTILITIES (DEPENDING ON HOW PROJECTS ARE STRUCTURED), AND PSC/PUCS': 1,
#              'SUPPORT THE AMERICAN WIND ENERGY ASSOCIATION (SOON AMERICAN CLEAN POWER ASSOCIATION), SOLAR ENERGY INDUSTRIES ASSOCIATION; AMERICAN COUNCIL ON RENEWABLE ENERGY; ENERGY STORAGE ASSOCIATION; REGIONAL CLEAN ENERGY TRADE ASSOCIATIONS; ENVIRONMENTAL NON-GOVERNMENTAL ORGANIZATIONS': 1,
#              'OPPOSE UTILITIES, EDISON ELECTRIC INSTITUTE, THE NATIONAL ASSOCIATION OF REGULATORY COMMISSIONS': 2,
#              'DOUBLING THE ENERGY STAR PROGRAM': 1,
#              'OVER 800,000 AMERICANS ARE ALREADY EMPLOYED IN INSTALLING OR MANUFACTURING ENERGY STAR  CERTIFIED PRODUCTS – OVER 30% OF THE ENERGY EFFICIENCY WORKFORCE IN 2019. EXPANDING THE  PROGRAM’S REACH WOULD CREATE NEW ECONOMIC ACTIVITY AND OPPORTUNITIES AROUND ENERGY STAR,  NOT JUST IN PRODUCTS BUT ALSO AROUND HOMES, BUILDINGS AND OTHER SECTORS.': 1,
#              'OVER 3.5 BILLION TONS OF GREENHOUSE GAS (GHG) EMISSIONS HAVE BEEN AVOIDED SINCE 1992  THANKS TO ENERGY STAR PRODUCTS – EQUIVALENT TO THE ANNUAL EMISSIONS OF 750 MILLION  AUTOMOBILES. IN ADDITION, ENERGY STAR ANNUALLY REDUCES U.S. GREENHOUSE GAS EMISSIONS BY  330 MILLION METRIC TONS – A REMARKABLE 5% OF THE NATION’S TOTAL ANNUAL EMISSIONS. GIVING  ENERGY STAR THE NECESSARY FUNDING TO PARTNER WITH MORE UTILITIES AND LOCAL GOVERNMENTS TO  BENCHMARK COMMERCIAL BUILDING ENERGY USE, FOR EXAMPLE, OR CREATE “MOST EFFICIENT” DESIGNATIONS  FOR MORE PRODUCT CATEGORIES WILL BOOST THESE ANNUAL EMISSIONS REDUCTIONS EVEN FURTHER.': 1,
#              'OPPOSE UTILITIES (DEPENDING ON HOW PROJECTS ARE STRUCTURED), PSC/PUCS (NOT NECESSARILY OPPOSED, BUT WOULD NEED TO BE CONVINCED TO ADOPT NATIONAL MODELS)': 1,
#              'ENVIRONMENTAL PROTECTION AGENCY, DEPARTMENT OF TRANSPORTATION': 2,
#              'A SUMMARY OF WHAT THE PROPOSAL IS': 1,
#              'WHAT PROBLEM IT IS SPECIFICALLY SOLVING': 1,
#              'TITLE EMISSIONS STANDARDS FOR NEW AND IN-USE AIRCRAFT AND AIRCRAFT ENGINES': 1,
#              'VERTICALS ENERGY, INFRASTRUCTURE, AUTO/MOBILITY': 1,
#              'PROGRAM TYPE PROGRAM MODIFICATION': 1,
#              'AUTHORITY EXISTING AUTHORITY, REQUIRES NEW REGULATION, REQUIRES NEW LEGISLATION': 1,
#              'TRIPLING FEDERAL FUNDING FOR CLEAN ENERGY RD&D CAN SUPPORT AT LEAST A MILLION JOBS OVER THE LONG RUN, AT A COST OF JUST $15,000/ JOB-YEAR. OVERALL, FEDERAL RD&D INVESTMENTS CREATE 2.7 INDIRECT JOBS FOR EVERY DIRECT JOB FUNDED, AND THE AVERAGE INCOME ACROSS ALL DIRECT JOBS AND THOSE INDUCED BY FEDERAL RD&D SPENDING IS $114,000 AND $77,000 PER PERSON, RESPECTIVELY.': 1,
#              'BACKGROUND ENERGY USAGE INFORMATION—ESPECIALLY GRANULAR INTERVAL DATA PROVIDED BY ADVANCED METERING INFRASTRUCTURE (AMI)—IS A KEY TOOL FOR DECARBONIZING BUILDINGS. ELECTRICITY AND NATURAL GAS DATA CAN BE USED TO IDENTIFY COST-EFFECTIVE ENERGY-SAVING OPPORTUNITIES, MEASURE THE PERFORMANCE OF SPECIFIC ENERGY EFFICIENCY MEASURES, AND DRIVE BEHAVIOR CHANGES AND EFFICIENCY INVESTMENTS THAT ACHIEVE MEASURABLE AND VERIFIABLE ENERGY SAVINGS. HOWEVER, UTILITIES CONTROL THAT DATA AND, IN MANY CASES, DO NOT READILY PROVIDE ACCESS TO CONSUMERS OR ALLOW THEM TO GRANT ACCESS TO THIRD-PARTY PROVIDERS WHO COULD PROVIDE DATA ANALYSIS, ACTIONABLE INSIGHTS, AND RECOMMENDATIONS. ESTABLISHING VOLUNTARY FEDERAL GUIDELINES WOULD HELP FACILITATE IMPROVED DATA ACCESS ACROSS THE COUNTRY, AND A DATA INNOVATION WORKING GROUP WOULD FURTHER ADVANCE THAT EFFORT.': 1,
#              'DOE TO ESTABLISH BEST PRACTICES FOR DATA ACCESS - HAVE THE SECRETARY OF ENERGY (DOE) ISSUE GUIDELINES THAT ESTABLISH MODEL DATA SHARING STANDARDS AND POLICIES FOR STATES TO PROVIDE ELECTRIC CONSUMERS AND GAS CONSUMERS, AND THIRD PARTIES THEY DESIGNATE, WITH ACCESS TO RETAIL ELECTRIC ENERGY INFORMATION AND RETAIL NATURAL GAS INFORMATION. THIS SHOULD INCLUDE GUIDELINES': 1,
#              'CREATE A DATA INNOVATION WORKING GROUP TO BUILD FROM THE EFFORTS OF THE  TO ENGAGE UTILITIES AND ENCOURAGE COMMITMENTS TO DATA PORTABILITY. THE WORKING GROUP SHOULD BE ALIGNED WITH THE DOMESTIC CLIMATE EFFORTS (THE WHITE HOUSE), GRID INTERACTIVE EFFICIENT BUILDINGS (DOE) AND CARBON MITIGATION (EPA) WORK TO MEASURE AND MANAGE ENERGY USE WITH A GOAL OF INCREASING UTILITY DATA ACCESS.': 1,
#              'SUMMARY BUILD ON THE EXISTING, SUCCESSFUL ED-GREEN RIBBON SCHOOLS PROGRAM TO PROVIDE STATES AND SCHOOLS THE EDUCATIONAL RESOURCES, TECHNICAL ASSISTANCE, AND INCENTIVES THEY NEED TO TAKE FULL ADVANTAGE OF FEDERAL SUPPORT FOR SCHOOL FACILITIES UNDER POTENTIAL STIMULUS OR INFRASTRUCTURE FUNDING, AND TO OPTIMIZE OPPORTUNITIES TO INTEGRATE ENVIRONMENTAL AND SUSTAINABILITY EDUCATION ALONGSIDE IMPROVEMENTS TO THE SCHOOL BUILDING.': 1,
#              'FUNDING - $17 MILLION PER YEAR': 1,
#              'GREEN SHIPPING AND PORTS POLICIES TO DECARBONIZE DOMESTIC SHIPPING AND IMPROVE AIR QUALITY': 1,
#              'SHIP BUILDERS – OPPORTUNITY FOR US SHIPBUILDERS AND COMPANIES ACROSS THE SHIPBUILDING SUPPLY CHAIN (INCLUDING ENGINE MANUFACTURERS AND FUEL CELL MANUFACTURERS) TO BECOME GLOBAL LEADERS IN ZERO EMISSION TECHNOLOGY WHICH STILL IS VERY NASCENT.': 1,
#              'PORTS – ECONOMIC ACTIVITY IN PORTS TO INSTALL NEW FUEL INFRASTRUCTURE – BOTH STORAGE AND BUNKERING FOR LIQUID FUELS AND ON SHORE ELECTRICITY.': 2,
#              'ENERGY – LARGE POTENTIAL FROM USING RENEWABLES AND POTENTIALLY CCS  TO PRODUCE GREEN HYDROGEN/BLUE THROUGH ELECTROLYSIS AND BLUE HYDROGEN/AMMONIA FROM STEAM REFORMATION OF NATURAL GAS WITH CCS. LARGEST POTENTIAL IN REGIONS THAT TODAY HAVE LARGE FOSSIL FUEL INDUSTRIES.': 2,
#              'OTHER - OFFERING MULTIPLE OPPORTUNITIES FOR SEAFARER TRAINING AND DEVELOPMENT OF A MODERN SHIPPING CREW, SEVERAL AREAS FOR GENERATION OF SUSTAINED AND SECURE LONG TERM EMPLOYMENT OPPORTUNITIES.': 2,
#              'GREEN HYDROGEN PROVIDES AN OPPORTUNITY TO DEVELOP A COMPLETELY NEW INDUSTRY CREATING A LARGE NUMBER OF HIGH PAYING JOBS, BOTH FOR UNIVERSITY GRADUATES AND FOR PERSONS WITHOUT DEGREES. FOR A BALLPARK ESTIMATE, THE EUROPEAN UNION’S FUEL CELLS AND HYDROGEN JOINT UNDERTAKING ESTIMATES THAT 5.4 MILLION JOBS CAN BE CREATED IN THE EUROPEAN UNION BY 2050 FROM GREEN HYDROGEN AND FUEL CELLS MARKETS ALONE.': 1,
#              'GREEN AND ZERO EMISSION PORT DEVELOPMENT WILL RESULT IN JOB CREATION IN ENGINEERING AND CONSTRUCTION, INCLUDING FOR UNION ELECTRICAL WORKERS AND UNIONED CONSTRUCTION WORKERS': 1,
#              'OPPOSITION': 2,
#              'SUPPORT': 2,
#              'PROGRAM MODIFICATION.': 1,
#              'REQUIRES NEW LEGISLATION.': 1,
#              'NOT PROGRAM': 1,
#              'REQUIRES NO NEW LEGISLATION': 1,
#              'SUPPORT FROM SEN LISA MURKOWSKI; OFFICE OF NAVAL RESEARCH; GOV JARED POLIS; ANY CONGRESSIONAL MEMBER WHO SUPPORTED THE 2014 WORKFORCE INNOVATION & OPPORTUNITY ACT': 1,
#              'HOPE FOR HOMES (116TH S.4052, H.R. 7325; ALSO INCLUDED IN H.R.2 AND H.R.4447)': 1,
#              'HOPE FOR HOMES IS EFFICIENT AND EFFECTIVE, SOLVING SEVERAL PROBLEMS AT ONCE': 1,
#              'WORKFORCE DEVELOPMENT NEEDS – PRIOR TO THE PANDEMIC, 2.3 MILLION AMERICANS WORKED IN ENERGY EFFICIENCY AND IT WAS THE FASTEST GROWING SECTOR IN THE ENERGY INDUSTRY. WORKFORCE DEVELOPMENT IS NEEDED TO PREPARE MORE AMERICAN WORKERS FOR THESE SKILLED LOCAL JOBS IN EVERY STATE, AND SMALL ENERGY EFFICIENCY BUSINESSES NEED ASSISTANCE TO HELP TRAIN NEW HIRES AND PROVIDE ONGOING EDUCATION TO EXISTING EMPLOYEES.': 1,
#              'OPPOSITION DOE, GOVERNMENT, AND NATIONAL LAB PERSONNEL WHO DO NOT WANT ADDITIONAL MANDATED TARGETS OR GOALS, OR WHO SEE THE PRIMARY ROLE OF THE NATIONAL LABS AS PUBLISHERS OF SCIENTIFIC PAPERS, OR WHO SEE STARTUPS AS TOO RISKY TO SUPPORT (I.E. BETTER TO LICENSE TECH TO LARGE CORPS, SINCE THEY ARE KNOWN QUANTITIES); POTENTIALLY, SOME FUNDING ORGANIZATIONS WHO WANT NATIONAL LAB TECH TO REMAIN A “HIDDEN GEM;” POTENTIALLY SOME NATIONAL LAB STAFF WHO SEE COMMERCIALIZATION AS A DISTRACTION FROM RESEARCH OR POTENTIALLY EXPOSING THEIR RESEARCH TO COMPETITION.': 1,
#              'MANDATE BUILDING ENERGY DISCLOSURE AND RESILIENCE ASSESSMENTS': 1,
#              'REFERENCES': 2,
#              'MANDATORY ELECTRIFICATION OF GOVERNMENT FLEETS THROUGH SECTION 141 OF THE ENERGY INDEPENDENCE AND SECURITY ACT OF 2007 (EISA 2007) FEDERAL VEHICLE FLEETS AND LOW GREENHOUSE GAS-EMITTING VEHICLES RULEMAKING': 1,
#              'SECTION 141 OF THE ENERGY INDEPENDENCE AND SECURITY ACT OF 2007 FEDERAL VEHICLE FLEETS AND LOW GREENHOUSE GAS-EMITTING VEHICLES': 1,
#              'REDUCTION IN COST. COULD BE INCLUDED IN A MAJOR INFRASTRUCTURE BILL. THE MONEY ALLOCATED TO THE DOE LOAN PROGRAM WOULD BE LOWERED BY THE VALUE OF THE TAX CREDITS GRANTED (COMPUTED AS $100,000 TIMES THE THEN-CURRENT MAXIMUM CORPORATE TAX RATE) THAT WERE RECAPTURED.': 1,
#              'NEW PROGRAM - “COMMUNITY ENERGY” IS A PROGRAM UNDER WHICH ELECTRIC CUSTOMERS “SUBSCRIBE” TO A COMMUNITY-BASED PROJECT, RATHER THAN INSTALLING SOLAR PANELS OR WIND TURBINES ON THEIR OWN PROPERTY. COMMUNITY SOLAR HAS BEEN SUCCESSFULLY DEPLOYED IN SEVERAL STATES, INCLUDING MINNESOTA, WITH A NATION-LEADING 750 MW INSTALLED TO DATE (SEE CASE STUDY BELOW).': 1,
#              '$417 BILLION IN CAPITAL INVESTMENT': 1,
#              '$15 BILLION TO LOW-INCOME SUBSCRIBERS': 1,
#              '$58 BILLION TO OTHER SUBSCRIBERS': 1,
#              '$10 BILLION IN PROPERTY TAX REVENUE TO LOCAL GOVERNMENTS': 1,
#              '$33 BILLION TO RURAL LANDOWNERS': 1,
#              '3.8 MILLION DIRECT JOBS': 1,
#              'NATIONAL COUNCIL ON WORKFORCE DEVELOPMENT TO COMBINE EXISTING DATA & TOOLS FOR INTERAGENCY COLLABORATION': 1,
#              'BARRIER #1  LACK OF A COORDINATED FEDERAL EFFORT ON CLEAN ENERGY WORKFORCE DEVELOPMENT.': 1,
#              'BARRIER #2 IT IS OFTEN UNCLEAR WHERE AND HOW CLEAN ENERGY JOBS ARE GEOGRAPHICALLY DISTRIBUTED, AND WHERE THEY ARE MOST NEEDED.': 1,
#              'BARRIER #3 LACK OF ACCESS TO THE RIGHT TRAINING TO BE HIRED FOR THESE CLEAN ENERGY JOBS.': 1,
#              'PROGRAM MODIFICATION, WITH COMPONENTS THAT CAN RECOMMEND NEW PROGRAMS OR INITIATIVES UTILIZING EXISTING FEDERAL AND PRIVATE RESOURCES, ASETS, FACILITIES AND CAPABILITIES.': 1,
#              'EXISTING AUTHORITY WHICH MIGHT BENEFIT FROM NEW LEGISLATION THAT WOULD SUPPLY ADDITIONAL FUNDING (VIA STANDARDIZED FOAS) TO VARIOUS EXISTING PROGRAMS IN MULTIPLE DEPARTMENTS.': 1,
#              'ADDITONAL REFERENCE MATERIALS AVAILABLE': 1,
#              'REFERENCE MATERIALS, INCLUDING CASE STUDIES, AND NON-U.S. EXAMPLES ARE INCLUDED IN APPENDIX A.': 1,
#              'APPENDIX A - EXAMPLES OF SUCCESSFUL CLEAN ENERGY TRAINING SITES': 1,
#              'REFERENCE MATERIALS FOR APPENDIX A': 1,
#              'RECOMMENDED ACTION': 1,
#              'ACTION MANDATE BY EXECUTIVE ORDER THE CREATION OF A NATIONAL ELECTRICITY INFRASTRUCTURE PLAN FOR A NATIONAL ELECTRIC TRANSMISSION SUPERHIGHWAY, UTILIZING EXISTING EXPERTISE AND EXPERIENCE': 1,
#              'PLANNING AUTHORIZE A CENTRALIZED PLANNING TEAM (THROUGH APPOINTED POSITION, COMMITTEE, OR AGENCY) IN CONJUNCTION WITH REGIONAL TRANSMISSION ORGANIZATIONS AND STATE REPRESENTATIVES TO DEVELOP A LONG-RANGE ENERGY INFRASTRUCTURE MASTER PLAN CONNECTING FAVORABLE PRODUCTION AREAS WITH ATTRACTIVE DELIVERY POINTS TO ENABLE VASTLY INCREASED UTILIZATION OF CLEAN ENERGY SUFFICIENT TO MEET CLIMATE GOALS WHILE OFFERING A TRANSITION PLAN FOR COMMUNITIES TO REPLACE DECLINING CARBON SECTOR JOBS WITH CLEAN ENERGY ECONOMIC OPPORTUNITIES.': 1,
#              'FUNDING DEPLOY FEDERAL FUNDING FOR TRANSMISSION PLANNING AND INVESTMENT, SUCH AS REFUNDABLE TAX INCENTIVES, GRANTS AND LOANS, INCLUDING AN ITC FOR TRANSMISSION, TO SUPPLEMENT IMPROVEMENT IN COST ALLOCATION; IDENTIFY AND REPURPOSE UNUSED ARRA FUNDS EARMARKED FOR RENEWABLE ENERGY DEPLOYMENT AND EXPANSION; ENCOURAGE AND UTILIZE PRIVATE OWNERSHIP, MERCHANT TRANSMISSION, AND INNOVATION WHERE PRACTICAL.': 1,
#              'SITING AND DEVELOPMENT EXPEDITE DEPLOYMENT OF A NETWORK OF HIGH VOLTAGE DIRECT CURRENT (HVDC) TRANSMISSION LINES, ENERGY STORAGE, AND OTHER INFRASTRUCTURE CONSISTENT WITH THE FEDERAL MASTER PLAN BY CLARIFYING REQUIREMENTS OF REGIONAL TRANSMISSION ORGANIZATIONS TO PLAN FOR INTERREGIONAL TRANSMISSION AND EQUITABLY ALLOCATE COSTS. WHEN PRACTICAL, ENCOURAGE INNOVATION AND UTILIZE EXISTING ROADS, PIPELINES, AND RAILWAY ROUTES TO REDUCE PROCEDURAL TIME FOR EXECUTION.': 1,
#              'COMMUNICATIONS PRIORITIZE MESSAGING OF TRANSMISSION EXPANSION AS A NATIONAL SECURITY AND PATRIOTIC IMPERATIVE AND ENGAGE EARLY WITH COMMUNITY-BASED ADVOCATES. PROMULGATE THE MISSION AS A 21ST CENTURY INFRASTRUCTURE OPPORTUNITY AND FAVORABLY COMPARE THE INITIATIVE TO THE SUCCESSFUL FEDERAL HIGHWAY PROGRAM FROM THE 1950S.': 1,
#              'ESTABLISHING OPEN-SOURCE COMMONS FOR TRUSTWORTHY CLIMATE DATA ORCHESTRATE A MULTI-STAKEHOLDER ECOSYSTEM WITH REPRESENTATIVES FROM THE PUBLIC AND PRIVATE SECTORS AS WELL AS CIVIL SOCIETY TO INFORM THE ARCHITECTURE, GOVERNANCE, OPERATION AND FUNDING OF OPEN-SOURCE DIGITAL INFRASTRUCTURE FOR ENERGY AND CLIMATE DATA. THIS INFORMATION WILL PROVIDE A COMMON PLATFORM FOR SOURCING DATA, INCREASING TRANSPARENCY AND IMPROVING SHARED LEARNINGS.': 1,
#              'DIGITIZING AMERICA’S INFRASTRUCTURE TO ENABLE REAL-TIME EMISSIONS REPORTING AND CARBON TRADING RETROFIT AMERICA’S INFRASTRUCTURE WITH TAMPER-PROOF, DECENTRALIZED SENSORS FOR REAL-TIME, TRUSTWORTHY EMISSIONS REPORTING. ON-BOARD REGULATORS, CORPORATES, SMES, SENSOR INSTALLATION COMPANIES AND EMISSIONS AUDITORS TO DEVELOP A SCALABLE MARKET FOR THE RETROFITTING OF LEGACY INFRASTRUCTURE AND SYSTEMS. THIS MODEL CAN PROVIDE A COMPETITIVE ADVANTAGE BASED ON OPEN STANDARDS AND CERTIFICATION IN CONJUNCTION WITH LEVERAGING AMERICA’S TECHNOLOGY LEADERSHIP IN HARDWARE MANUFACTURING.': 1,
#              'EXPANDING THE FEDERAL DATA STRATEGY (EG, FERC STRATEGIC PLAN 2018-2022) TO FACILITATE PUBLIC TRUST AND UNDERSTANDING AND IMPROVE EVIDENCE-BASED POLICYMAKING. ASSIST CONSUMERS IN OBTAINING ENERGY DATA WHILE IMPROVING THE MONITORING, REPORTING, AND VERIFICATION OF EMISSIONS FROM VARIOUS SOURCES (EG, LNG, LFG, RENEWABLES, ELECTRICITY INITIATIVES, ETC.).': 1,
#              'CONTRIBUTOR(S) NAME AND TITLE(S)': 2,
#              'BIAS': 1,
#              'VERTICAL(S)': 2,
#              'IDEA DESCRIPTION/PROBLEM BEING SOLVED': 1,
#              'FRICTION/IMPEDIMENTS TO SCALING': 1,
#              'NECESSARY ACTIONS FOR SCALING': 1,
#              'IMPACT': 1,
#              'I.REVENUE/SAVINGS/ECON ACTIVITY': 1,
#              'II.JOB CREATION': 1,
#              'III.GHG BENEFITS': 1,
#              'IV.ENVIRONMENTAL JUSTICE': 1,
#              'INCREASE SECTION 5312 FUNDING FOR FTA RESEARCH AND INNOVATION': 1,
#              'DIRECT OTHER COMPETITIVE PROGRAMS TO INCENTIVIZE INNOVATIVE TRANSIT PROJECTS (LOW/NO COST)': 1,
#              'CONTRIBUTOR’S NAME & TITLE': 1,
#              '1) LEAD BY EXAMPLE BY INSTALLING CHARGING INFRASTRUCTURE AT FEDERAL PROPERTIES SET A STRONG EXAMPLE AND FACILITATE EV ADOPTION BY REQUIRING THAT ALL FEDERAL CAPITAL PROJECTS – FROM OFFICE BUILDINGS TO NATIONAL PARKS – INCORPORATE EV CHARGERS, BOTH WITH NEW CONSTRUCTION AND WITH RENOVATIONS AND UPDATES TO EXISTING CONSTRUCTION. MOREOVER, MAKE FEDERAL WORKPLACE CHARGERS PUBLICLY ACCESSIBLE WHEN NOT IN USE BY EMPLOYEES, PARTICULARLY IN HIGH VISIBILITY PUBLIC LOCATIONS.': 1,
#              '2) DRIVE INNOVATION WITH AN EVSE “SUNSHOT” INITIATIVE MODELED ON THE SUNSHOT INITIATIVE, DOE SHOULD ESTABLISH A SET OF RECOMMENDED BEST PRACTICES, MODEL CODES, AND COMPETITIVE GRANTS FOR PILOTS AND DEMONSTRATION PROJECTS TO EXPEDITE TIMETABLES AND DRIVE COSTS DOWN FOR THE REVIEW, PERMITTING, AND INSTALLATION OF EV CHARGING INFRASTRUCTURE.': 1,
#              '3) ESTABLISH REBATES FOR EVS, L2 CHARGING, OR PUBLIC CHARGING CREDITS FOR FRONTLINE COMMUNITIES, MODELED ON THE CARB PROGRAM IN PARTNERSHIP WITH GRID ALTERNATIVES WHERE UNDERSERVED/FRONTLINE/RURAL COMMUNITIES CAN NOT ONLY GET A REBATE FOR A (NEW OR USED) EV, BUT ALSO GET AN L2 INSTALLED FOR FREE OR TAKE PUBLIC CHARGING CREDIT.': 1,
#              'DIRECT FUNDING TOWARDS PURCHASING AND/OR SUBSIDING DONATION OF FRESH PRODUCE. THIS COULD BE DONE THROUGH THE FOLLOWING ACTIONS, ORGANIZED FROM EASIEST TO HEAVIEST LIFT.': 1,
#              'EXISTING AUTHORITY, REQUIRES NEW REGULATION': 1,
#              'REQUIRE FEDERAL PROCUREMENT OF CARBON-NEUTRAL OR CARBON-NEGATIVE CONCRETE TO SEQUESTER CARBON AND CREATE DOMESTIC JOBS': 1,
#              'A SPECIFIED PROCUREMENT PREFERENCE FOR ZERO OR NEGATIVE CARBON CONCRETE IN FEDERAL TRANSPORTATION PROJECTS, WHERE AVAILABLE AT A COMPETITIVE PRICE, WOULD SIGNIFICANTLY ACCELERATE THE SCALING OF THESE TECHNOLOGIES. THIS COULD BEGIN WITH THE FEDERAL HIGHWAY ADMINISTRATION. IT SHOULD BE NOTED THAT THE CALCULATED PRICE SHOULD RECOGNIZE AND INCLUDE THE VALUE OF CO2 REDUCED AND SEQUESTERED (HOWEVER, THIS WOULD REQUIRE LEGISLATION).': 1,
#              'MUCH OF AMERICA’S INFRASTRUCTURE IS ALREADY PRIVATIZED. ACCORDING TO THE U.S. BUREAU OF ECONOMIC ANALYSIS, THE NET VALUE OF FIXED ASSETS OWNED BY THE FEDERAL AND STATE/LOCAL GOVERNMENTS IS $1.5 AND $10.1 TRILLION RESPECTIVELY, WHILE THE PRIVATE SECTOR OWNED $40.7 TRILLION IN 2015. ELECTRIC TRANSMISSION, FOR EXAMPLE, MAY BE DIFFICULT TO LEASE TO THE PRIVATE SECTOR, SINCE PRIVATE UTILITIES ALREADY PROVIDE 70% OF U.S. ELECTRICITY. THERE REMAINS, HOWEVER, A LARGE NUMBER OF PUBLICLY-OWNED UNUSED OR UNDERUTILIZED ASSETS PERFECT FOR SALE OR LEASE TO PRIVATE INVESTORS TO RAISE SUBSTANTIAL AND SORELY NEEDED INFRASTRUCTURE FUNDS.': 1,
#              'PUBLIC ACCEPTANCE OF PRIVATE INFRASTRUCTURE MANAGEMENT IS ESSENTIAL. ACCORDING TO A 2018 REPORT RELEASED ON AUSTRALIA’S ASSET RECYCLING PROGRAM, “PREVIOUS NEGATIVE EXPERIENCES WITH PRIVATIZATION IN A COUNTRY MAY CAUSE LASTING DAMAGE TO PUBLIC PERCEPTION OF ASSET RECYCLING.” STRICT PUBLIC OVERSIGHT WOULD STILL BE REQUIRED TO MAINTAIN PUBLIC CONFIDENCE AS WELL AS INFRASTRUCTURE  QUALITY.': 1,
#              'WORKS CITED/CONSULTED': 1,
#              'PROGRAM MODIFICATION, NEW PROGRAM, NOT PROGRAM': 1,
#              'SMALL BUSINESS ENERGY EFFICIENCY GRANT (SBEEG) PROGRAM': 1,
#              'DECARBONIZATION OF THE HARD-TO-REACH SMALL BUSINESS SECTOR, PRIORITIZING SMALL BUSINESSES  IN UNDERSERVED COMMUNITIES. SMALL BUSINESSES ARE UNDERSERVED BY UTILITY DEMAND-SIDE MANAGEMENT (DSM) PROGRAMS IN THE BEST OF TIMES. WHILE SMALL BUSINESSES ACCOUNT FOR 40-50%  OF A UTILITY’S AGGREGATE ENERGY DEMAND, THESE CRITICAL BUSINESSES RECEIVE ON AVERAGE LESS THAN  4% (ACEEE 2016) OF UTILITY INVESTMENT IN DSM, INCLUDING ENERGY EFFICIENCY AND DEMAND  RESPONSE. SMALL BUSINESSES ARE THE BACKBONE OF THE U.S. ECONOMY, EMPLOYING HALF OF ITS  WORKFORCE AND PRODUCING HALF OF ITS GDP. DUE TO THE COVID-19 PANDEMIC, MILLIONS OF SMALL  BUSINESSES ARE CURRENTLY SHUTTERED AND AT RISK OF PERMANENT CLOSURE. THE SMALL BUSINESS ENERGY EFFICIENCY GRANT (SBEEG) PROGRAM WOULD PROVIDE GRANTS TO QUALIFYING UTILITIES (INVESTOR OWNED, PUBLICLY-OWNED, RURAL COOPERATIVES, AND STATE-AUTHORIZED THIRD-PARTY PROGRAM  ADMINISTRATORS) TO SUPPLEMENT EXISTING OR NEW UTILITY INCENTIVES TO SMALL BUSINESS PARTICIPANTS SO  THAT ENERGY UPGRADES CAN BE MADE AT ZERO COST TO THE SMALL BUSINESS. BY UTILIZING AN EXISTING  DELIVERY MECHANISM (DSM PROGRAMS ARE OPERATED BY 74% OF NATURAL GAS AND ELECTRIC UTILITIES IN  NEARLY EVERY STATE) WITH ROBUST EXISTING STATE-LEVEL OVERSIGHT AND RIGOROUS COST-EFFECTIVENESS TEST  REQUIREMENTS, ENSURING RAPID DELIVERY OF STIMULUS FUNDING TO THE SMALL BUSINESS PARTICIPANTS.  THE PROGRAM WOULD NOT ONLY STIMULATE JOB CREATION IN THE ENERGY EFFICIENCY DELIVERY AND  MANUFACTURING SECTORS, BUT WOULD ALSO RETAIN EXISTING JOBS ON MAIN STREET, IMPROVING THE  ECONOMIC COMPETITIVENESS OF THESE CRITICAL EMPLOYERS. SEVENTY-NINE PERCENT (79%) OF ENERGY  EFFICIENCY EMPLOYERS ARE SMALL BUSINESSES WITH FEWER THAN 20 EMPLOYEES (E2 2019)  THEMSELVES, MEANING THE SBEEG PROGRAM WOULD BE SMALL BUSINESSES HELPING SMALL  BUSINESSES. THESE ARE JUST SOME OF THE REASONS THE PROPOSAL HAS GARNERED ENDORSEMENTS  FROM NEARLY 60 DIVERSE STAKEHOLDERS, INCLUDING UTILITIES, ENVIRONMENTAL AND ENERGY EFFICIENCY  ADVOCATES, GOVERNMENTAL OFFICIALS, TRADE ASSOCIATIONS AND ENERGY SERVICES COMPANIES.': 1,
#              'SOURCES DIRECTLY RECOMMENDING OR ANALYZING SMALL BUSINESS ENERGY EFFICIENCY GRANT  (SBEEG) PROGRAM': 1,
#              'ADDITIONAL REFERENCES': 1,
#              'SPEEDING THE DEPLOYMENT OF DEEP ENERGY RETROFITS': 1,
#              'ACTIONS REQUIRING FUNDING': 1,
#              'MATCHING GRANTS TO COVER DEEP ENERGY RETROFIT INDUSTRY FUNDING OF PLANT, EQUIPMENT & TECHNOLOGY ACQUISITION COSTS': 1,
#              'SUPPORT WARRANTIES FOR DEEP ENERGY RETROFIT SOLUTIONS BY CREATING A CAPITAL RESERVE FUND TO BACKSTOP THE RISK OF THE WARRANTY': 1,
#              'REDUCED MORTGAGE INTEREST RATES FOR NZE/NZC BUILDINGS': 1,
#              'NET ZERO ENERGY TAX CREDIT': 1,
#              'NO COST ACTIONS': 1,
#              'AVOIDABLE HEALTH COSTS FUNDING MECHANISM': 1,
#              'CHANGE DOD & GSA PROCUREMENT POLICIES TO REQUIRE DEEP ENERGY RETROFITS': 1,
#              'HUD FUNDING CRITERIA': 1,
#              'LENDER CARBON DISCLOSURE & TRANSPARENCY': 1,
#              'CONTRIBUTOR NAME & TITLE GO LAB, INC.137 HIGH STREET, BELFAST, ME, JOSH HENRY, CO-FOUNDER, 207-233-1737': 1,
#              'THIS PROPOSAL WOULD DRIVE AND SCALE DEEP ENERGY RETROFITS IN EXISTING COMMERCIAL BUILDINGS VIA GRANTS TO STATES THROUGH STATE ENERGY OFFICES (SEOS). STATES ARE CLOSEST TO THE OWNERS AND CAN GAUGE WHAT APPROACHES WILL BE MOST EFFECTIVE IN EACH MARKET. FUNDING FOR STATES WOULD BE ALLOCATED BY FORMULA. SEOS COULD USE FUNDING FOR THE FOLLOWING AUTHORIZED ACTIVITIES': 1,
#              '1.          PROPOSAL TITLE': 1,
#              'SUNSHOT 2.0, ENSURE US MARKET LEADERSHIP IN GREEN HYDROGEN SET AND PURSUE GOAL OF PRODUCING 8GW GREEN HYDROGEN BY 2026 AND $1.25/KG BY 2030': 1,
#              '2.          VERTICALS': 1,
#              '3.          CONTRIBUTOR(S) NAME(S) & TITLE(S)': 1,
#              '4. DISCLOSURE OF ANY CONFLICT OF INTEREST': 1,
#              '5.          OPPORTUNITY/PROBLEM BEING SOLVED': 1,
#              '6. IMPEDIMENTS TO IMPLEMENTATION': 1,
#              '7. RECOMMENDED ACTIONS': 1,
#              '8. INVOLVED AGENCIES AND/OR PROGRAMS': 1,
#              '11. FUNDING': 1,
#              '12. ECONOMIC BENEFITS': 1,
#              '13.JOB CREATION': 1,
#              '14.          ENVIRONMENTAL BENEFITS': 1,
#              '15.          EQUITY BENEFITS': 1,
#              '16.       STAKEHOLDER SUPPORT AND OPPOSITION': 1,
#              'WHAT GETS MEASURED GETS MANAGED, AND, PRIORITIZED, AND DONE.  SMALL CHANGES IN METRICS OR PERFORMANCE MEASUREMENT CAN DRAMATICALLY CHANGE MARKETS, BEHAVIORS, AND OUTCOMES.': 1,
#              'BELOW GRAPH ILLUSTRATES THE JOBS, ECONOMIC, AND ENVIRONMENTAL IMPACT': 1,
#              'STAKEHOLDER SUPPORT/OPPOSITION': 2,
#              'PROGRAM MODIFICATION, NEW PROGRAM': 1,
#              'TRANSFORM ALL PUBLIC BUILDINGS BY REIMAGINING THE USE OF FEDERAL ENERGY SAVINGS PERFORMANCE CONTRACTS (ESPCS) CREATING “A NATIONAL ESPC COLLABORATIVE”': 1,
#              'CONTRIBUTOR NAME & TITLE': 1,
#              'JOBS, ECONOMIC, AND ENVIRONMENTAL IMPACTS DESCRIBED BELOW': 1,
#              'US STEPS UP TO FILL LEADERSHIP VACUUM IN INTERNATIONAL MARITIME ORGANIZATION, SETS AND PUSHES FOR PARIS ALIGNED TARGETS AND REGULATION': 1,
#              'FOSSIL FUEL PRODUCING GOVERNMENTS – GOVERNMENTS PRODUCING OIL AND NATURAL GAS ARE IN GENERAL HINDERING PROGRESS ON CLIMATE TOPICS': 1,
#              'PROGRAM MODIFICATION, MODIFICATION OF EXISTING LEGISLATION': 1,
#              'DISCLOSURE OF ANY CONFLICT OF INTERESTS': 1,
#              'EXISTING AUTHORITY (FIRST SET OF ACTIONS), REQUIRES NEW LEGISLATION (SECOND SET OF ACTIONS)': 1,
#              'ACCESS TO CUSTOMER DATA HELD BY UTILITIES FOR ACCELERATING POWER SECTOR DECARBONIZATION': 1,
#              'BUILDING SECTOR, INCLUDING HOMES, & OWNERS OF C&I BUILDINGS/FACILITIES, AND BUILDING MANAGERS': 1,
#              'BUILDING SERVICE PROVIDERS, ESCOS, DER/DR/DG/STORAGE INTEGRATORS AND AGGREGATORS': 1,
#              'SMART ENERGY APPLICATIONS DEVELOPERS AND SERVICE PROVIDERS DEPENDENT ON ACCESS TO DATA': 1,
#              'PROBLEM CLEAN ENERGY PROJECTS ARE MORE EXPENSIVE THAN THEY SHOULD BE BECAUSE ELECTRIC UTILITIES MAKE IT DIFFICULT FOR CUSTOMERS TO SHARE THEIR ENERGY DATA WITH DER PROVIDERS. FOR EXAMPLE, QUALIFYING A PROSPECTIVE CUSTOMER FOR BEHIND-THE-METER SOLAR, STORAGE, ENERGY EFFICIENCY OR DEMAND RESPONSE REQUIRES ACCESS TO 15-MINUTE ENERGY USAGE HISTORY, BUT EACH OF AMERICA’S 3,500 UTILITIES AND RETAIL PROVIDERS HAVE DIFFERENT METHODS AND PROCESSES FOR CUSTOMERS TO GRANT THEIR CONSENT, AS WELL AS DIFFERENT FORMATS OF THE DATA, LIMITING THE APPLICABILITY OF SOFTWARE TOOLS FOR AUTOMATION AND COST REDUCTION. UTILITIES ALSO RECEIVE FAR FROM OPTIMUM VALUE FROM DERS BECAUSE THEY LACK DATA ABOUT DISTRIBUTED RESOURCES AND LOAD MANAGEMENT SYSTEMS.  RECIPROCAL DATA EXCHANGE WOULD CUT DER SOFT COSTS, ENABLE RESIDENTIAL DER AGGREGATORS TO COST-EFFECTIVELY ENTER THE MARKET, AND SIGNIFICANTLY INCREASE FLEXIBLE LOAD RESOURCES ACROSS THE COUNTRY.': 1,
#              'OPPORTUNITY ACCESS TO DATA (BY THIRD-PARTY APPLICATIONS AND UTILITIES) WILL IMPROVE THE VALUE OF DERS ON BOTH SIDES OF THE METER.  SOLVING THIS PROBLEM WILL REQUIRE FAR LESS TIME AND INVESTMENT TO RESOLVE THAN RAMPING UP ACTUAL DISTRIBUTED RESOURCES, BUILDING UPGRADES, OR SMART SYSTEMS.  PRIVATE INVESTMENTS IN ALL THESE WILL ACCELERATE EXPONENTIALLY IF A SIMPLE, UNIFIED, COST-EFFECTIVE SYSTEM FOR SECURE DATA SHARE WERE TO EMERGE FOR THE AMERICAN MARKET.  MUCH HAS ALREADY BEEN DONE, INCLUDING ADOPTION OF THE “GREEN BUTTON STANDARD” BY THE NORTH AMERICAN ENERGY STANDARDS BOARD, AFTER LONG WORK BY DOE AND NIST BEGINNING IN THE FORMER OBAMA/BIDEN ADMINISTRATION. HOWEVER, PROGRESS STALLED IN THE LAST 4 YEARS. ( SEE ATTACHED ISSUE OVERVIEW.)': 1,
#              'THE CURRENT PARADIGM': 1,
#              'THE SOLUTION': 1,
#              'THE BETTER AMERICA CHALLENGE UNLEASHES EXISTING FEDERAL PROGRAMS TO BUILD A CLEANER, MORE PRODUCTIVE, AND MORE EQUITABLE ECONOMY. THE CHALLENGE CAN ENABLE A RAPID TRANSITION TO A LOW CARBON ECONOMY THAT LOWERS COSTS, CREATES HIGH-PAYING JOBS, AND REVITALIZES THE COMMUNITIES THAT HAVE POWERED OUR ECONOMY FOR GENERATIONS – AND BORNE THE BURDENS OF POLLUTION FROM THAT ROLE. BY REWARDING PUBLIC AND PRIVATE SECTOR EFFORTS TO DO MORE WITH LESS CARBON, THE CHALLENGE WILL UNLEASH ACTION THAT QUICKLY REDUCES CARBON EMISSIONS WHILE PROVIDING FUNDING TO SUPPORT FAMILIES, BUSINESSES, AND CITIES AS THEY WORK TO RECOVER FROM THE COVID PANDEMIC.': 1,
#              'HELP AMERICANS DO MORE WITH LESS CARBON, BY PROVIDING FINANCIAL ASSISTANCE TO PRIVATE AND PUBLIC ENTITIES TO ENABLE THEM TO DELIVER GOODS AND SERVICES OF EQUAL OR GREATER VALUE WITH LOWER CARBON EMISSIONS RELATIVE TO PRE-COVID TIMES;': 1,
#              'ACHIEVE CARBON EMISSIONS REDUCTION TARGETS WHILE LOWERING COSTS, BY TYING FINANCIAL ASSISTANCE TO THE AMOUNT OF CARBON REDUCED WHILE REQUIRING ALL RECIPIENTS TO DEMONSTRATE HOW THEY CAN DO THIS WHILE REDUCING THE COSTS OF ANY GOODS OR SERVICES FOR CUSTOMERS;': 1,
#              'CREATE HIGH-PAYING JOBS BY INVESTING IN THE FUTURE OF COMMUNITIES THAT POWERED OUR ECONOMY, BY REQUIRING THAT ALL RECIPIENTS PAY PREVAILING WAGES (OR BETTER) TO WORKERS AND PROVIDE HARDSHIP ASSISTANCE AND NEW OPPORTUNITIES FOR DISLOCATED WORKERS AND COMMUNITIES, WHILE TASKING THE DEPARTMENT OF ENERGY TO CLEAN UP AND REDEVELOP FOSSIL ENERGY SITES AND SURROUNDING COMMUNITIES THAT HAVE SHOULDERED DISPROPORTIONATE BURDENS FROM FOSSIL ENERGY POLLUTION; AND': 1,
#              'JUMPSTART THE RECOVERY THROUGH RAPID AUTHORIZATION, FUNDING, AND IMPLEMENTATION, USING LEGISLATIVE PATHWAYS THAT LEVERAGE EXISTING AUTHORITIES AND GOVERNMENT CAPABILITIES AND COULD BE EXECUTED THROUGH BUDGET RECONCILIATION IN THE FIRST YEAR OF THE NEXT ADMINISTRATION.': 1,
#              'HOW DOES THE CHALLENGE WORK?': 1,
#              'MODIFY THE 45Q TAX CREDIT TO APPLY TO MITIGATION OF GREENHOUSE GAS EMISSIONS AT $35 PER METRIC TON OF CO2E, AND ALLOW IT TO BE TAKEN BY ANY ENTITY REGARDLESS OF TAX STATUS AS A DIRECT PAY TAX CREDIT. TREASURY, EPA, AND DOE WOULD BE RESPONSIBLE FOR DEVELOPING RULEMAKING THAT REQUIRES RECIPIENTS TO DEMONSTRATE ACHIEVEMENT OF PERMANENT, ADDITIONAL CARBON EMISSIONS REDUCTIONS, SIMILAR OR INCREASED LEVELS OF ECONOMIC ACTIVITY, COST REDUCTIONS FOR CUSTOMERS, JOB CREATION, AND COMMUNITY BENEFITS.': 2,
#              'ALTERNATIVE (POSSIBLY VIA EXECUTIVE ACTION) – ALLOW ANY FEDERAL TAX OR DEBT OBLIGATION TO BE REPAID IN CARBON MITIGATION CREDITS, AT A LEVEL CONSISTENT WITH EITHER THE SOCIAL COST OF CARBON OR THE EFFECTIVE CARBON PRICE IMPLICIT IN THE 45Q TAX CREDIT. THIS PATHWAY COULD BE ENABLED BY MODIFICATIONS TO THE FEDERAL CREDIT REFORM ACT (FCRA). IT MAY ALSO BE POSSIBLE WITH EXECUTIVE ACTION ALONE BY TREASURY AND THE FEDERAL RESERVE, THOUGH SUCH ACTION MAY BE VULNERABLE TO LEGAL CHALLENGES RELATED TO CREDIT BUDGETARY ACCOUNTING.': 2,
#              'REMOVE RESTRICTIONS ON DOE LOAN GUARANTEES TO MAKE  LOW COST REFINANCING  AVAILABLE TO HELP REDUCE THE BURDEN OF TRANSITION FROM EXISTING FOSSIL INFRASTRUCTURE NATIONWIDE, BY ALLOWING USE OF EXISTING SUBSIDY COST FOR LENDING IN SUPPORT OF 45Q FINANCED ACTIVITIES.': 1,
#              'EMPOWER DOE TO ADDRESS THE LEGACY OF FOSSIL ENERGY POLLUTION ON US LANDS AND COMMUNITIES, BY EXPANDING THE DOE’S OFFICE OF ENVIRONMENTAL MANAGEMENT’S MISSION BEYOND NUCLEAR WASTE REMEDIATION AND APPROPRIATING $100 BILLION IN RECOVERY FUNDING TO FULLY REMEDIATE, RESTORE, AND REDEVELOP FOSSIL ENERGY SITES AS WELL AS THE COMMUNITIES IMPACTED BY POLLUTION FROM FOSSIL ENERGY PRODUCTION AND USE AS HUBS FOR CLEAN ECONOMIC GROWTH ACROSS THE COUNTRY.': 2,
#              'SAMPLE USE CASE – COAL PLANT PHASEOUT AND REPLACEMENT WITH SOLAR, WIND, AND STORAGE': 1,
#              'SOCIETAL COSTS AND BENEFITS WITH A COMMITMENT FROM THE UTILITY’S REGULATOR TO USE A DEDICATED SURCHARGE TO REPAY THE FEDERAL GOVERNMENT, THE COST TO GOVERNMENT OF THE LOAN IS MINIMAL (SINCE THERE IS LITTLE TO NO RISK OF DEFAULT). THE 45Q DIRECT PAY CREDITS WOULD COST TAXPAYERS $4.2 BILLION OVER 12 YEARS WHILE THE RESTORATION AND REDEVELOPMENT SUPPORT REQUIRES AN ADDITIONAL $1 BILLION, FOR A TOTAL OF $5.2 BILLION IN COSTS. LOCAL COMMUNITIES WOULD SEE $2.4 BILLION IN LOST WAGES AND PROPERTY TAXES, WHILE THE MINE OWNER WOULD SEE LOSSES OF ROUGHLY $1.8 BILLION, LEADING TO A TOTAL DIRECT COST OF $9.4 BILLION OVER 12 YEARS. HOWEVER, THIS PROGRAM WOULD RESULT IN ROUGHLY $4.3 BILLION IN CUSTOMER SAVINGS OVER THAT TIME PERIOD RELATIVE TO CONTINUED OPERATION OF THE PLANT – AND HAVE CREATED $6.5 BILLION IN ADDITIONAL INVESTMENT AND $3 BILLION IN WAGES AND PROPERTY TAXES FROM THOSE INVESTMENTS IN THE REGION – FOR A TOTAL OF $13.8 BILLION IN BENEFITS, ALL WHILE AVOIDING 120 MILLION METRIC TONS OF CO2E. THAT IS, THIS USE CASE DEMONSTRATES HOW THIS INVESTMENT CAN RESULT IN 0.12 BILLION METRIC TONS OF CARBON REDUCTIONS AT A NET DIRECT ECONOMIC BENEFIT OF $4.4 BILLION – A NET CARBON COST OF -$37 PER TON OF CO2E.': 1,
#              'BETTER AMERICAN CHALLENGE SUPERCHARGE THE 45Q TAX CREDIT AND DOE LOAN AND CLEAN-UP PROGRAMS TO LOWER COSTS AND DRIVE AN EQUITABLE LOW CARBON TRANSITION': 1,
#              'REMOVE RESTRICTIONS ON DOE LOAN GUARANTEES TO MAKE LOW-COST REFINANCING AVAILABLE TO HELP REDUCE THE BURDEN OF TRANSITION FROM EXISTING FOSSIL INFRASTRUCTURE NATIONWIDE, BY ALLOWING USE OF EXISTING SUBSIDY COST FOR LENDING IN SUPPORT OF 45Q FINANCED ACTIVITIES.': 1,
#              'CREATING A 2050 NATIONAL SITING STRATEGY FOR THE SUBSTANTIAL VOLUME OF INTERIOR RESOURCES (PRIVATE LAND) REQUIRED TO ACHIEVE THE BIDEN ADMINISTRATION’S CLIMATE MITIGATION GOALS': 1,
#              'APPENDIX': 1,
#              'THREE MAPS TELL THE STORY OF THE LOCATION FOR THIS NEXT, SUBSTANTIAL WAVE OF CONSTRUCTION AND THE MILLIONS OF ACRES OF LAND THAT WILL BE NEEDED': 1,
#              'NOTES JUST FOR FEASIBILITY COMMITTEE -- PLEASE KEEP CONFIDENTIAL PER BOB KOZAK, PRESIDENT, ATLANTIC BIOMASS, LLC': 1,
#              '§7404. RESEARCH RELATING TO FUELS AND VEHICLES': 1,
#              '(A) RESEARCH PROGRAMS; GRANTS; CONTRACTS; PILOT AND DEMONSTRATION PLANTS; BYPRODUCTS RESEARCH': 1,
#              'DISAPPEARING FUEL CARBON TAX': 1,
#              'ENERGY, AUTO/MOBILITY, ENVIRONMENTAL JUSTICE.': 1,
#              'RENEWABLE FUEL R&D\xa0AN IMMEDIATE APOLLO-TYPE PROGRAM SHOULD BE FUNDED WITH BETWEEN 50% AND 60% OF THE FEES. IT SHOULD BE\xa0ADMINISTERED BY THE NATIONAL SCIENCE FOUNDATION\xa0(NSF) AND BE FOCUSED ON GETTING NON-FOOD BIOMASS FUELS AND GASES INTO THE PIPELINE IN LESS THAN SEVEN YEARS. A SUSTAINABLE RENEWABLE FUEL INDUSTRY WILL NOT ONLY CUT PETROLEUM IMPORTS AND TREMENDOUSLY REDUCE US OIL AND GAS EXTRACTION DAMAGE, BUT MORE IMPORTANT, CREATE GOOD JOBS FOR AMERICANS IN RESEARCH LABS, RURAL TOWNS, AND URBAN MANUFACTURING PLANTS AND CONVERTED OIL REFINERIES.': 1,
#              'RENEWABLE FUEL INFRASTRUCTURE THE UPGRADED FUEL PUMPS AND DECENTRALIZED PROCESSING/DISTRIBUTION MODULES WOULD BE FUNDED WITH BETWEEN 40% AND 50% OF THE FEES. THESE PROGRAMS WOULD BE\xa0RUN BY THE STATES\xa0WITH FUNDING AVAILABLE VIA THE EXISTING USDA GRANT PROGRAM. STATES KNOW WHAT THE NEEDS ARE AND THE MOST EFFECTIVE WAYS TO ADDRESS THEM.\xa0 PRIORITY COULD BE GIVEN TO LOW INCOME AND HIGH POLLUTION AREAS, RURAL AND URBAN.': 1,
#              'COLLECTION OF THE NON-RENEWABLE CARBON USER FEE': 1,
#              'NEW PROGRAM AND PROGRAM (HIGHWAY USER FEE) MODIFICATION,': 1,
#              'CONTACT PLEASE SEND YOUR COMPLETED SUBMISSIONS TO OUR DIRECTORS OF POLICY RESEARCH. KALEN DAVISON ()   ORIANA TANNENBAUM ()': 1,
#              'CURRENT STATUS AT AGENCIES WHERE NEW OR UPDATED GUIDANCE IS NEEDED (HUD, SBA, USDA)': 1,
#              'CURRENT STATUS AT GSES WHERE SUPPORT FOR C-PACE FROM THE BIDEN ADMINISTRATION COULD SERVE AS A CATALYST FOR IN-DEPTH REVIEW OF PROCEDURES AND ACCEPTANCE': 1,
#              'ENABLED BY DIRECT U.S. GOVERNMENT ACTION (EE/RE+RESILIENCY)': 1,
#              'TOTAL U.S. MARKET POTENTIAL, CATALYZED BY GOVERNMENT ACTION & ADDITIONAL COMPREHENSIVE POLICY (EE/RE+RESILIENCY)': 1,
#              'LIMITATIONS': 1,
#              'SUPPORT SO FAR, 57 COMPANIES, TRADE ASSOCIATIONS, AND ENVIRONMENTAL NON-PROFIT ORGANIZATIONS HAVE SIGNED ON TO THE GOOD FOOD INSTITUTE’S LETTER TO CONGRESS IN SUPPORT OF ALTERNATIVE PROTEIN R&D FUNDING IN FY22 APPROPRIATIONS, INCLUDING 50BY40, AMERICAN MUSHROOM ASSOCIATION, AMERICAN PULSE ASSOCIATION, THE BREAKTHROUGH INSTITUTE, CONSUMER REPORTS, GREENPEACE, MERCK KGA (DARMSTADT, GERMANY), PLANT BASED FOODS ASSOCIATION, WATERKEEPER ALLIANCE, AND UNILEVER.': 1,
#              'OPPOSITION THERE MAY BE FUTURE OPPOSITION FROM SOME CATTLEMEN AND DAIRY ASSOCIATIONS THAT SEE ALTERNATIVE PROTEINS AS COMPETITION.': 1,
#              'SIMULTANEOUSLY ADDRESS EFFICIENCY, RESILIENCY, SAFETY, AND FLEXIBILITY IN PUBLIC BUILDINGS. U.S. PUBLIC BUILDINGS – MILITARY FACILITIES, FEDERAL, STATE AND LOCAL PUBLIC BUILDINGS, SCHOOLS AND HOSPITALS – ARE CRITICAL INFRASTRUCTURE THAT ENABLE FEDERAL, STATE, AND LOCAL GOVERNMENTS TO FULFILL THEIR MISSIONS. IN THE EVENT OF A PUBLIC HEALTH CRISIS OR NATURAL DISASTER, PUBLIC BUILDINGS CAN ALSO DELIVER LIFE-SAVING SERVICES AND CAPACITY FOR TEMPORARY HEALTHCARE, EMERGENCY SHELTER AND OTHER COMMUNITY RELIEF OPERATIONS. BUT AS WE HAVE SEEN IN THE COVID-19 CRISIS, MANY OF THESE FACILITIES ARE IN DIRE NEED OF IMPROVEMENTS TO MEET MODERN DEMANDS. OVER MANY YEARS, MUCH OF THIS INFRASTRUCTURE HAS DECAYED, BUILDING UP A DEFERRED MAINTENANCE BACKLOG ESTIMATED TO BE MORE THAN $1 TRILLION. UNDER THIS PROPOSAL, FEDERAL APPROPRIATIONS WOULD BE LEVERAGED TO DRAW PRIVATE INVESTMENT FOR MORE THAN $100 BILLION IN UPGRADES TO PUBLIC FACILITIES NATIONWIDE.': 1,
#              'NATIONAL NATURE SERVICE RAPIDLY CREATE THOUSANDS OF GREENS JOBS WHILE RESTORING AMERICA’S NATURAL CAPITAL': 1,
#              'NEW PROGRAM (OR EXPANSION OF WEATHERIZATION PROGRAM)': 1,
#              'REQUIRES NEW REGULATIONS, BUT COULD BE CONSIDERED AN EXPANSION OF WEATHERIZATION PROGRAM.': 1,
#              'RESPONSE TO QUESTIONS REGARDING THE': 1,
#              'SOLAR, WEATHERIZATION, AND ELECTRIFICATION PACKAGE (SWEP) PROPOSAL': 1,
#              'NATIONAL SECURITY BENEFITS': 1,
#              'ECONOMIC AND ENVIRONMENTAL BENEFITS': 1,
#              'EQUITY AND JOB BENEFITS': 1})

# %%
def count_diff(header, val):
    count = 0
    for s in difflib.ndiff(header, val):
        if s[0]==' ': continue
        elif s[0]=='-':
            count+=1
        elif s[0]=='+':
            count+=1
    return count

# %%
def get_differences(doc, header):
    differences = {}
    for paragraph in doc.paragraphs:
        val = paragraph.text
        val = val.replace('\t','').replace('\n','')
        if not re.search(pat, val) and len(val)>1:
            differences[val] = count_diff(header.upper(), val.upper())
    return differences

def get_header(doc, header):
    diffs = get_differences(doc, header)
    return list(diffs.keys())[np.argmin(list(diffs.values()))]

def get_header_index(doc, header):
    diffs = get_differences(doc, header)
    return np.argmin(list(diffs.values()))

# %%
def filter_out_bad_headers(doc):
    real_headers = []
    for search_header in SEARCHING_HEADERS:
        real_headers.append(get_header(doc, search_header))
    return real_headers

filter_out_bad_headers(docx.Document(filenames[100]))
# Out:
# ['Proposal Title',
#  'Verticals',
#  'Contributor(s) Name(s) & Title(s)',
#  'Disclosure of Any Conflict of Interest',
#  'Opportunity/Problem Being Solved',
#  'Impediments to Implementation',
#  'Recommended Actions',
#  'Program Type',
#  'Authority',
#  'Involved Agencies and/or Programs',
#  'Funding',
#  'Economic Benefits',
#  'Job Creation',
#  'Environmental Benefits',
#  'Equity Benefits',
#  'Stakeholder Support and Opposition',
#  'Key Experts']
